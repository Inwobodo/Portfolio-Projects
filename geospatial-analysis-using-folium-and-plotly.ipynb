# %% [markdown]
# <a href="https://www.kaggle.com/code/ifeanyichukwunwobodo/geospatial-analysis-using-folium-and-plotly?scriptVersionId=130750369" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Introduction
#
# Geospatial data science is becoming a popular field in data science as corporations are starting to learn abbout it's usefulness. This is because many stakeholders are now paying attention to the importance od making decisions using spatial data.
#
# According to the [IBM](https://www.ibm.com/topics/geospatial-data), geospatial data is information that describes objects, events or other features with a location on or near the surface of the earth.  [Wikipedia](https://en.wikipedia.org/wiki/Geographic_data_and_information) defines it as data and information having an implicit or explicit association with a location relative to Earth.
#
# This notebook explores how to create and find patterns in map using the two very popular data visualization libraries, Folium and Plotly Express. Folium is a specialized library  for visuliazing maps while plotly is a library for data visualization as a whole. That means, if you already know how to visualize in plotly you can easily integrate geospatial data visualization
#
# Enough with the talk. Let's get our hands dirty.

# %%
import math #for basic maths calculation 
import numpy #for linear algebra
import pandas as pd # for data manipulation and basic data visualization

# For Data Visualization
import plotly.express as px

# for geographical analysis we use
import geopandas as gpd #To read our data 
import folium #for interactive maps
from folium import Circle, Marker #to select the maptype we want to use
from folium.plugins import HeatMap, MarkerCluster #for plugins
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# For this we are going to use a geojson file obtained from GRID which contains geeogarphical data on the various factories and industrial sites (for the rest of this notebook, this will be reffered to simply as "Factories" in Lagos.

# %%
factories = gpd.read_file('/kaggle/input/lagos-georeferenced-dataset/factoriesindustrial-sites.geojson')
#Let's take a look at the first few rows
factories.head()
# Out:
#                                   id state_code source  \
# 0   u_fc_poi_factory_industry_site.1         LA   GRID
# 1   u_fc_poi_factory_industry_site.2         LA   GRID
# 2   u_fc_poi_factory_industry_site.4         LA   GRID
# 3  u_fc_poi_factory_industry_site.11         LA   GRID
# 4  u_fc_poi_factory_industry_site.18         LA   GRID
#
#                               name  status ward_code  \
# 0  JJ International Block Industry  In Use  LASIUI05
# 1            Kadiri Block Industry  In Use  LASIUI04
# 2                      Teju Blocks  In Use  LASIKU29
# 3      Adurumigba Block Industries  In Use  LASBDY08
# 4                Abllat Nig Co Ltd  In Use  LASAMO24
#
#                               global_id                 geometry
# 0  000b39d0-ba96-4d62-91f3-52bef3d64890  POINT (3.78227 6.47244)
# 1  001a5124-6f66-457f-ac1b-c4f1fde6a61a  POINT (3.68407 6.46090)
# 2  004d7b39-d3b8-4074-b270-d0fc09a20510  POINT (3.54362 6.59287)
# 3  006bb17c-b0fc-4b09-acc4-59250acdcfce  POINT (3.03417 6.46336)
# 4  0097ec77-7a51-44a4-a83d-c15f67e03fad  POINT (3.25955 6.52691)

# %%
print( "The factories dataset contains", factories.shape[0], "rows and", factories.shape[1], "columns")
# Out:
# The factories dataset contains 732 rows and 8 columns

# %%
factories.columns.to_list()
# Out:
# ['id',
#  'state_code',
#  'source',
#  'name',
#  'status',
#  'ward_code',
#  'global_id',
#  'geometry']

# %%
#Let's keep the
factories = factories[['name', 'status', 'geometry']]

# %% [markdown]
# * 'name': The name of the factory. This will be used to identify the factory.
#
# * 'status': refers to the state of the factory.
#
# * 'geometry': geometry refers to the location of the factories.

# %%
#Let's check for missing values
factories.isna().sum()
# Out:
# name        0
# status      0
# geometry    0
# dtype: int64

# %% [markdown]
# There are no missing values in our dataset.

# %% [markdown]
# ## Brief Introduction to Geographical Analysis
# Let's create Longitude ('lon') and Latitude ('lat') columns from the 'geometry' column.
# Longitude is a geographic coordinate that specifies the east–west position of a point on the surface of the Earth, or another celestial body. We are going to focus on earth in this notebook foe obvious reasons.
# If longitude is the east-west position of a point on earth's surface, latitude is the north-south position of a point on earth's surface.

# %%
factories['lon'] = factories.geometry.apply(lambda p: p.x)
factories['lat'] = factories.geometry.apply(lambda p: p.y)

# %% [markdown]
# ### Coordinate Reference System

# %% [markdown]
# Another key concept we are going to look at is the the Cordinate Reference Systems (or CRS for short). The erath is a globe so representing it on a flat surface requires us to make some assumptions. This is where CRS comes in. These are different rmaps representation that make different assumptions about the projection of earth on a flat surface.

# %%
print(factories.crs)
# Out:
# epsg:4326

# %% [markdown]
# For example, the CRS of our dataset according to  European Petroleum Survey Group (EPSG) codes is 4326 which corresponds to longitude and latitudes.

# %% [markdown]
# # Visualizing Geospatial Data

# %% [markdown]
# ### How Does Mapping in Python Work?

# %% [markdown]
# Mapping in python is just like any other visualization except that the background image is a map. For example, a circle map (which we will talk about later) is the equivalent of a scatter plot of the longitude and latitude of the factories.

# %%
px.scatter(factories, 'lon', 'lat', 
           title='A Scatter Plot of the Latitude and  Longitude of Factories in Lagos'
          )
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c4ebca9c-ce46-48db-88b2-a21723b1c1e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4ebca9c-ce46-48db-88b2-a21723b1c1e9")) {                    Plotly.newPlot(                        "c4ebca9c-ce46-48db-88b2-a21723b1c1e9",                        [{"hovertemplate":"lon=%{x}<br>lat=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.7822694,3.6840657,3.5436183,3.0341748,3.2595483,3.4940271,3.2797783,3.4884096,3.3341333,3.5471293,3.5844349,3.5287173,3.2479046,3.8459144,4.1253959,3.3459393,3.3629133,3.7540898,4.0639683,3.6717089,3.3223893,3.6450411,3.7700664,3.3673881,3.6682425,3.7074939,3.2538021,3.2579501,3.3633999,3.3508418,3.2584812,3.6565878,3.3046987,3.3544045,4.1168533,3.3176446,3.2555425,3.8529733,3.2071543,3.5271126,3.5482144,3.2611436,3.4843224,3.3387967,3.3253575,3.8423195,3.368434,3.5673449,3.673053,3.2236954,3.6832776,3.3373967,3.6245734,3.6548483,3.8518289,3.7156617,3.4804002,3.3615705,3.3662867,3.2776874,3.499595,3.3368825,3.4921573,3.2461654,3.5982791,3.7826036,3.2269955,3.3644141,3.6678625,3.2426633,2.9759406,3.3265252,3.499548,3.2340183,3.2263445,3.3497048,3.5213516,3.7831861,3.7098909,3.9679087,3.3420757,3.5779647,3.477095,3.4874255,3.5865343,3.2073931,3.523365,3.3767167,3.669078,3.3450995,3.5212115,3.967866,3.3743584,3.3559736,3.8825914,3.6981767,4.0546812,3.5848197,3.3406264,3.3003603,3.5217034,3.2909718,3.6300969,3.2642569,3.3683342,3.
# *Step 1: Create a basemap. The basemap include the location (longitude and latitude of area of interest), tiles (which can be thought about as the theme the map displays) and zoom_start (this shows how 'focused you want your initial map to be). Since the graph is interactive, the audience can change the size/focus of the image manually to get greater details of the map. That is, it can be zoomed down to country level, state level, street level and so on.
#
# *Step 2: Add the plugins. The plugins can be a marker, circle, heatmap, markercluster (for bubble charts) and so on which you add to your basemap using the 'add_to' function. The choice of plugin depends on the goal of the visualization.
#
# *Step 3: Checkout the amazing map you just created.

# %%
# Unhash this comment to learn more about maps in Folium and run cell
# ?? folium.Map

# %% [markdown]
# ### Markers on Folium (Mark Your Territory)
#
# Markers show different points in a geospatial data. The map shows a pin on different location of interest (factories) in the map.

# %%
# Create a base map
mark = folium.Map(location=[6.5244, 3.3792],
                  tiles='cartodbpositron', zoom_start=12)

# Add plugin, in this case, markers

for idx, row in factories.iterrows():
    Marker([row['lat'], row['lon']], 
           popup='name' #popup shows what you want displayed when you over the map
          ).add_to(mark)


# Display the map
mark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_499b03b4ea24f4b6841039672bb79da9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_499b03b4ea24f4b6841039672bb79da9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_499b03b4ea24f4b6841039672bb79da9 = L.map(
#                 &quot;map_499b03b4ea24f4b6841039672bb79da9&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9e823b08ae02e500c68bf6fb5d742c3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_499b03b4ea24f4b6841039672bb79da9);
#
#
#             var marker_caa27448fcfbbff7d934f714ebdd2ea8 = L.marker(
#                 [6.4724391, 3.7822694],
#                 {}
#             ).addTo(map_499b03b4ea24f4b6841039672bb79da9);
#
#
#         var popup_41b645f9058afab0973958a5d95e6769 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed9be27fda60b31c4323039e08532b68 = $(`&lt;div id=&quot;html_ed9be27fda60b31c4323039e08532b68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_41b645f9058afab0973958a5d95e6769.setContent(html_ed9be27fda60b31c4323039e08532b68);
#
#
#
#         marker_caa27448fcfbbff7d934f714ebdd2ea8.bindPopup(popup_41b645f9058afab0973958a5d95e6769)
#         ;
#
#
#
#
#             var marker_c4e46a79f2671e60eca913a59b96841e = L.marker(
#                 [6.4609044, 3.6840657],
#                 {}
#             ).addTo(map_499b03b4ea24f4b6841039672bb79da9);
#
#
#         var popup_a25c78b9f4151709c8606d1dd1453d7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d89f8ca54de8e93c654e87a4346c287 = $(`&lt;div id=&quot;html_4d89f8ca54de8e93c654e87a4346c287&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_a25c78b9f4151709c8606d1dd1453d7a.setContent(html_4d89f8ca54de8e93c654e87a4346c287);
#
#
#
#         marker_c4e46a79f2671e60eca913a59b96841e.bindPopup(popup_a25c78b9f4151709c8606d1dd1453d7a)
#         ;
#
#
#
#
#             var marker_0fc8bde470b5ddcd7fc566ed406c2e17 = L.marker(
#                 [6.59287, 3.5436183],
#                 {}
#             ).addTo(map_499b03b4ea24f4b6841039672bb79da9);
#
#
#         var popup_0526b46d44b94ba09ae4a164a326235f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3f3e7d3985c3777fb176977f9faef76 = $(`&lt;div id=&quot;html_e3f3e7d3985c3777fb176977f9faef76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_0526b46d44b94ba09ae4a164a326235f.setContent(html_e3f3e7d3985c3777fb176977f9faef76);
#
#
#
#         marker_0fc8bde470b5ddcd7fc566ed406c2e17.bindPopup(popup_0526b46d44b94ba09ae4a164a326235f)
#         ;
#
#
#
#
#             var marker_7e08eef84383dfd7de48da715fd2ff40 = L.marker(
#                 [6.4633558, 3.0341748],
#                 {}
#             ).addTo(map_499b03b4ea24f4b6841039672bb79da9);
#
#
#         var popup_cd810dc6ad3737cd2d562a2f6ebb2dcd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91d6a05708ef1f9398e2e69f034b2c9d = $(`&lt;div id=&quot;html_91d6a05708ef1f9398e2e69f034b2c9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_cd810dc6ad3737cd2d562a2f6ebb2dcd.setContent(html_91d6a05708ef1f9398e2e69f034b2c9d);
#
#
#
#         marker_7e08eef84383dfd7de48da715fd2ff40.bindPopup(popup_cd810dc6ad3737cd2d562a2f6ebb2dcd)
#         ;
#
#
#
#
#             var marker_c4293b2aa22132137a7bb943920e1415 = L.marker(
#                 [6.526905, 3.2595483],
#                 {}
#             ).addTo(map_499b03b4ea24f4b6841039672bb79da9);
#
#
#         var popup_d028578f0921ae277595633b01e73696 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_706fed8f61e15c8e3a0a084d203e6b45 = $(`&lt;div id=&quot;html_706fed8f61e15c8e3a0a084d203e6b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_d028578f0921ae277595633b01e73696.setContent(html_706fed8f61e15c8e3a0a084d203e6b45);
#
#
#
#         marker_c4293b2aa22132137a7bb943920e1415.bindPopup(popup_d028578f0921ae277595633b01e73696)
#         ;

# %% [markdown]
# Does the distribution of the markers look familiar? It should. That's because they are the same as the distribution on the scatterplot.

# %%
# Unhash this comment to learn more about markers
# ?? Marker

# %% [markdown]
# If you zoom out you would notice that the number of factories reduces as you come closer to the western borders (towards Cotonou).
#
#
# You can play with the map by zooming in and out on any part of the map you are interested in. If you have ever been to Lagos you can check out if you recognize any street or factory on the map.
#
# **Question 1: What did happens to the number of factories as you head towrds the Eastern border?**

# %% [markdown]
# ### Bubble Charts on Folium (Burst the Bubble)
#
# The bubble map shows a bubble to indicate a location at different points in the map. One cool thing about the bubble map is that it also shows the amount of 'factories' at the different locations of interest. It gets more granular as you zoom in.

# %%
#create a basemap
bubble = folium.Map(location =[6.5244, 3.3792], 
                       zoom_start =12,tiles ='cartodbpositron')

#Add Plugins
mc = MarkerCluster()
for idx, row in factories.iterrows():
    mc.add_child(Marker([row['lat'], row['lon']]))
bubble.add_child(mc)

#Display Bubble Chart
bubble
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_653ecc34e6c882567daa2029934b4501 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_653ecc34e6c882567daa2029934b4501&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_653ecc34e6c882567daa2029934b4501 = L.map(
#                 &quot;map_653ecc34e6c882567daa2029934b4501&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44a7b66fc6eda57c9a7d8ff41b695899 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_653ecc34e6c882567daa2029934b4501);
#
#
#             var marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef = L.markerClusterGroup(
#                 {}
#             );
#             map_653ecc34e6c882567daa2029934b4501.addLayer(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_423dad652cf8c69692aa5beaa7da167a = L.marker(
#                 [6.4724391, 3.7822694],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_6a8abec59c58d5ab1b4bc278b409c322 = L.marker(
#                 [6.4609044, 3.6840657],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_5431022bae74d31dcc131ee9c55d18d5 = L.marker(
#                 [6.59287, 3.5436183],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_14a7fa567fad7f5d8ce861450183b12c = L.marker(
#                 [6.4633558, 3.0341748],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_2c4be60a36c6be16d250ffd9c3041e77 = L.marker(
#                 [6.526905, 3.2595483],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_eafe9bedff4c1a42d66f09145d88ac07 = L.marker(
#                 [6.6786892, 3.4940271],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_f1587db77ef9bdac42b0fa7897c0fcf6 = L.marker(
#                 [6.5280467, 3.2797783],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_6228c348ec4e823dcabbb05e73b9bc91 = L.marker(
#                 [6.5861481, 3.4884096],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_12eed676e87cc4550bbf20c0a26ad260 = L.marker(
#                 [6.6600383, 3.3341333],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_b41c1bd51637523527a4f19639e73622 = L.marker(
#                 [6.6537608, 3.5471293],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_e99a98863da584a70b10ad45f2b88fb5 = L.marker(
#                 [6.6570728, 3.5844349],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_eeb439ba733791691fb5fa5b8801446b = L.marker(
#                 [6.6675921, 3.5287173],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_936e78c617f284867689e469c594950c = L.marker(
#                 [6.5207974, 3.2479046],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_eb9a01f3a8a5700deb90ee4b16d87c97 = L.marker(
#                 [6.475655, 3.8459144],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_3d621f07f2a837cd7c82b44f3c25615f = L.marker(
#                 [6.4116961, 4.1253959],
#                 {}
#             ).addTo(marker_cluster_20160e52c54cac2327b8e2c0bb75c6ef);
#
#
#             var marker_8a2c9db1701698d1e969f7aea5513ca6 = L.marker(

# %% [markdown]
# In the map above, the points on the map with a only one factory are represented by markers. The green colored bubble shows when data point is less than 10. The yellow shows the factories are greater than 10. This is not the color scheme in all situations.
#
# **Question 2: What is the total number of factories in Lagos?**
#
# Hint: The more you zoom out the less granular the map becomes.

# %% [markdown]
# ### HeatMap on Folium (Bring In the Heat)

# %% [markdown]
# Heatmap shows the concentration of data points on a map. The heatmap
#
# Note: It is easier to answer Question 1 with the heatmap.

# %%
#Learn more
#??HeatMap

# %%
heat = folium.Map(location=[6.5244, 3.3792], tiles='cartodbpositron', zoom_start=10)

# Add a heatmap to the base map
HeatMap(data=factories[['lat', 'lon']], radius=10).add_to(heat)

# Display the map
heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32a37261e20ca9c653e2c97ecaad5e96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32a37261e20ca9c653e2c97ecaad5e96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32a37261e20ca9c653e2c97ecaad5e96 = L.map(
#                 &quot;map_32a37261e20ca9c653e2c97ecaad5e96&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed6f12bd639b07c73c6da8f9cb82a03c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map
5162545, 3.890177], [6.4635752, 3.3180868], [6.6013771, 3.3745478], [6.4431252, 2.8857371], [6.5467085, 3.3536464], [6.5908984, 3.6243709], [6.500535, 3.28263], [6.5645214, 3.251517], [6.6497317, 3.3589283], [6.4107643, 4.1282776], [6.4776408, 3.313848], [6.6059133, 3.3383586], [6.626247, 3.3412858], [6.45404, 3.3659933], [6.6809787, 3.5319326], [6.4865146, 3.3548281], [6.5099779, 3.2649584], [6.4933021, 3.1736632], [6.5000864, 3.0137219], [6.6708872, 3.6683269], [6.6512983, 3.5769467], [6.4828267, 3.30374], [6.4001698, 4.1763626], [6.4354555, 3.3644957], [6.450521, 3.2742297], [6.5347302, 3.2202113], [6.4432094, 3.6607951], [6.5896282, 3.5942926], [6.4712247, 3.7927364], [6.6272079, 3.349745], [6.4204367, 4.0695967], [6.6111323, 3.3367671], [6.5885498, 3.6012989], [6.562432, 3.2499094], [6.6715433, 3.3359717], [6.6178596, 3.3456575], [6.615285, 3.3420506], [6.6722339, 3.5275359], [6.4294036, 2.998432], [6.6378254, 3.2591173], [6.4527278, 3.3293885], [6.5780833, 3.2326533], [6.655001,

# %% [markdown]
# ### Circle Map in Folium (Sraight to the Point)

# %%
status = factories.groupby('status').count().reset_index() #To get the count of the different categories


px.bar(status, #The data we use for our visualization
       color= 'status', #the variable you want to use to color the dataset
       color_discrete_map={'In Use': 'blue', 'Unused Good':'yellow', 'Unused Poor': 'purple'}, #the color for each unique values of the variable 
       title='Status of Factories and Indistrial Sites in Lagos') #Title of your visualization
# Out:
# <div>                            <div id="696d4855-8fab-4181-8c53-0cbe646db8ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("696d4855-8fab-4181-8c53-0cbe646db8ea")) {                    Plotly.newPlot(                        "696d4855-8fab-4181-8c53-0cbe646db8ea",                        [{"alignmentgroup":"True","hovertemplate":"status=In Use<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"In Use","marker":{"color":"blue","pattern":{"shape":""}},"name":"In Use","offsetgroup":"In Use","orientation":"v","showlegend":true,"textposition":"auto","x":[0,0,0,0],"xaxis":"x","y":[701,701,701,701],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=Unused Good<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Unused Good","marker":{"color":"yellow","pattern":{"shape":""}},"name":"Unused Good","offsetgroup":"Unused Good","orientation":"v","showlegend":true,"textposition":"auto","x":[1,1,1,1],"xaxis":"x","y":[21,21,21,21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=Unused Poor<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Unused Poor","marker":{"color":"purple","pattern":{"shape":""}},"name":"Unused Poor","offsetgroup":"Unused Poor","orientation":"v","showlegend":true,"textposition":"auto","x":[2,2,2,2],"xaxis":"x","y":[10,10,10,10],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...

# %% [markdown]
# You might want to add layers to your map by showing the different categories of the points in your map. That is, by showing a bivariate relationship you can show more detail in a map. A circle map can help by showing the spatial distribution of status of the factories in Lagos shown in the bar chart above.

# %%
#add basemap
circle = folium.Map(location=[6.5244, 3.3792], tiles='cartodbpositron', zoom_start=10)

# create conditions to colour the datapoints on  the map
def color_producer(val):
    if val == 'In Use':
        return 'blue'
    elif val == 'Unused Good':
        return 'yellow'
    else:
        return 'purple'

# Add the circle map to the base map
for i in range(0,len(factories)):
    Circle( #add the plugins
        location=[factories.iloc[i]['lat'], factories.iloc[i]['lon']], #for the different latitude and longitude on the map
        radius=20,
        color=color_producer(factories.iloc[i]['status'])).add_to(circle)

# Display the map
circle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd4115c0a0ff482650734f8fba1b4b2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd4115c0a0ff482650734f8fba1b4b2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd4115c0a0ff482650734f8fba1b4b2d = L.map(
#                 &quot;map_cd4115c0a0ff482650734f8fba1b4b2d&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0bc5c1110d62baf8462cec55806f107 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cd4115c0a0ff482650734f8fba1b4b2d);
#
#
#             var circle_c0eaf7de86d2c140e6801bfc0842cf3f = L.circle(
#                 [6.4724391, 3.7822694],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd4115c0a0ff482650734f8fba1b4b2d);
#
#
#             var circle_23e692cf587fe17af1e409afda5894fa = L.circle(
#                 [6.4609044, 3.6840657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd4115c0a0ff482650734f8fba1b4b2d);
#
#
#             var circle_c93ebc7e19c1675b9521ef589225770e = L.circle(
#                 [6.59287, 3.5436183],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd4115c0a0ff482650734f8fba1b4b2d);
#
#
#             var circle_694dc8f79ea47b962a35f6912d9508bd = L.circle(
#                 [6.4633558, 3.0341748],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd4115c0a0ff482650734f8fba1b4b2d);
#
#
#             var circle_42dd06da1685c0ae000e3ec485b57606 = L.circle(
#                 [6.526905, 3.2595483],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd4115c0a0ff482650734f8fba1b4b2d);
#
#
#             var circle_0c0d21ae7cf360336a267136103bc1d9 = L.circle(
#                 [6.6786892, 3.4940271],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd4115c0a0ff482650734f8fba1b4b2d);

# %% [markdown]
# Just as seen in the bar chart, the 'In use' factories are more densely distributed than other factories.
# As seen above, the circle map shows your map in form of a scatter plot. And you can add more layers like increasing the radius of the circle map by size and shapes. This is easier to do with plotly express. That brings us to our next tool.
#
# **Question 3: Is there a pattern in the location of the various factories based on status?**

# %% [markdown]
# ## Visualising Maps in Plotly

# %% [markdown]
# Plotly Express is the easy-to-use, high-level interface to Plotly, which operates on a variety of types of data and produces easy-to-style figures. Plotly Express provides functions to visualize a variety of types of data. Geospatial analytics is used to add timing and location to traditional types of data and to build data visualizations.
#
# Geospatial data is most useful when it can be discovered, shared, analyzed and used in combination with traditional business data. Plotly makes this easier as you can use combine geospatial data without jumping between different libraries.
#
# Plotly graphs have more interactive options than Folium. You can save image,pan,box select, lasso select, zoom in and out and reset the graph using the icons in the top right corner of the visualization.

# %%
# scatter_mapbox creates a circle map. The remaining in the first line is exactly what they imply                
fig = px.scatter_mapbox(factories,lat=factories.lat, lon=factories.lon, zoom=10, color='status',
                        #This defines the color for each status
                        color_discrete_map={'In Use': 'blue', 'Unused Good':'yellow', 'Unused Poor': 'purple'},
                        #The equivalent of tiles in Folium
                        mapbox_style="carto-positron", 
                        #for those familiar with tableau this is the same as tooltips. It shows information on the various datapoints
                        hover_name='name')
#update layout in plotly defines the aesthetic of various visuals.
fig.update_layout(margin=dict(l=0, r=0, t=30, b=10)) 
fig.show()
# Out:
# <div>                            <div id="c7ca64a9-93eb-40e3-a9d6-a4df6875ca7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c
# %% [markdown]
# In this case, l, r, t and b stands for left, right, top and bottom margins. You can play with the values and find out what it does.
#  The various mapbox_style in available in plotly are 'white-bg','carto-positron','carto-darkmatter', 'stamen-terrain','stamen-toner','stamen-watercolor'.
#
# **Question 4: What are the names of the 'Unused Poor Factories?**

# %%
#?? px.scatter_mapbox

# %% [markdown]
# ### Heatmap in Plotly

# %% [markdown]
# The density_mapbox is used to create a heatmap in plotly.

# %%
fig = px.density_mapbox(factories, lat='lat', lon='lon', radius=15, #radius determines the size of each point. 
                        #The same as the location in the basemap of Folium
                        center=dict(lat=6.5244, lon= 3.3792), zoom=9,
                        #The color scale you want to use in your map
                        color_continuous_scale='viridis',
                        mapbox_style="carto-positron", hover_name='name')
fig.update_layout(margin=dict(l=0, r=0, t=30, b=10))
fig.show()
# Out:
# <div>                            <div id="d095e2a4-54ef-45d9-b10b-f9c998ecc306" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d095e2a4-54ef-45d9-b10b-f9c998ecc306")) {                    Plotly.newPlot(                        "d095e2a4-54ef-45d9-b10b-f9c998ecc306",                        [{"coloraxis":"coloraxis","hovertemplate":"<b>%{hovertext}</b><br><br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["JJ International Block Industry","Kadiri Block Industry","Teju Blocks","Adurumigba Block Industries","Abllat Nig Co Ltd","Maras Nig Enterprises","Ade Block","GOS Block Industry","International Envelopes Limited","Abey Tos Block Industry","Ayegbemi Block Industry","Hossana Block Industry","Aqua Crown Pure Water","Block Industry 29","Owoyele Block Industry","Stellar Construction Limited","Mediterranean Shipping Company","Dredging Service Industry","Oladele Block Industry","Block Industry 1","Givanas Industries Nigeria Limited","Adex Block Industry","De Sholly Nigeria Limited","Honeywell Flour Mills Plc","B S Wood Industry","Olabanji Block Industry","Bee Printing Mechanical Company","Opeyemi Investment Company","SMC Ltd","Sid Industries","Taiwo Block Industry","Aros Vibrated Block Industry","Dee United Hardware Ltd","Ebonylife Channel Company","Seriki Plank Factory","Twyford England Sanitary Wares","Kolafem Water","Alhaji Folawuyo Block Industry","Kayus Block Industry","Sunflag Nigeria Limited Ikorodu Unit","Aqua Solo Water","Block Industry","MTN","Oloyin Table Water","Akinwande Factory","Bamtefa Block Industry","Delta Industries","Kay And Tee Block Industry","SA Wood Industry","Transformer Company","Ibukun Oluwa Block Industry","Bashorun Owoyemi Block","God Is My Helper Block Industry","Bock Industry","Sodiq Plank Factory","Lucky Star Block Industry","Winnes Block Industry","The Fish Shop Apapa","MTN Centre Calcutta","De Unique Bond","Ladipupo Block Industry","PMP Pioneer Metal Product Company","Balo Block Industries","Iya Ope Block Industry","Golden Street Sawmill","One Love Block Industry","Alfa Kunfayakun Block Industry","Azin Engineering Limited","Aquaville Sachet Water Factory","Ablad Evers Block Industry","Bobo Small Block Industry","Saso Industries Ltd","Owolabi Adekoya and Co Ring And Block Industry","Embassy Enterprise","Beat Adeshina Steel Construction Works","SPN Industries","Albarika Block Industry","Forbor Block Industry","Ayore Block Industry","Customs Processing Center","Nigerchin Electrical Development Company Limited","Baale Block Industry","Block Industry Asolo Market","Wabilahi Taofik","Pacific Down","Givers Water Company","Nylon Company Area","FMB System","Abusi Oluwa Block Industry","PSC Solar Uk","Oreta RoadNear Ambras Block","Asia Africa International Fze","Julius Berger","Bagco Factory","Block Factory 40","Olanrewaju Favour Bread","Industrial Site","Block Industry 15","Guinness Nigeria PLC","Factory Warehouse","Ikorodu Steel Nigeria Limited","Urels Sachet And Bottle Water","Afolabi Block Industry 1","SP Stones","Aiteo Company","Bio Vaccines Nigeria Limited","ENL Consortium Limited","Zenon Cosmetics","Bola Block Industry","Young Ade Concrete Block And Cement","Mama Lemon Dish Washing Liquid","Ore Ofe Oluwa Block Industry","J O Oluwalogbon Block Industry","Tamaap Wood Industry","La Casera Factory","Plastic Factory","Pure Water Factory","Kimberty Clark Company","Alubarika Block Industry","Friyo Block Industry","Recycling Industry","Bakery","Abbey Block Industry","Factory","WAHUM Ltd","Wemco Factory","Olam Sanyo Foods LtdApapa","Ola Block Industry 1","Sun Flag Nigeria Limited","Paper Industry","Ogo Oluwa Block Industry","De Crown Farm Garri Factory","Arab Concrete Works","Honey Block Industry","Maxbe Ltd","Jide Block Industry","Niger Biscuit Company Ltd","Star And Lu ...

# %%
#You can learn about different color scales by unhashing the following and running the cells 

#??px.colors.diverging
#??px.colors.sequential
#??px.colors.cyclical

# %%
#You can learn more about heatmap in plotly by unhashing the comment and running the cell

#??px.density_mapbox

# %% [markdown]
# A good way to learn different colour scale to use in your visualisation is to use a wrong input (instead of 'viridis' try 'vidiis' or something like that). An error message will appear showing different options available to you.
#
# To the best of my knowlege there is no way to create a bubble map or map with markers in Plotly (as shown with folium. If there is anyway you know of you can drop a link or leave a comment in the comment section.

# %% [markdown]
# # What Next?
#
# The best way to learn more is to read the [plotly map documentation](https://plotly.com/python/maps/) and [folium documentation](https://python-visualization.github.io/folium/).
#
# You can cement your knowledge by trying out these datasets (you can try out the other dataand [geotagged flickr images dataset](https://www.kaggle.com/datasets/ifeanyichukwunwobodo/tokyo-geotagged-flickr-images)). You can also see how to apply your newly gained knowledge to a project using this [link](https://www.kaggle.com/code/ifeanyichukwunwobodo/exploratory-analysis-of-co2-emission-using-plotly. You can also learn how to create different maps from the base knowledge obtained from this notebook by exploring the various maps in used here to explore Co2 Emission around the world (co2 emission notebook). You can also improve your map visualization skill by adding animation and increasing size of different points in your circle map based on the continuous values used there.

# %% [markdown]
# # Conclusion
#
# Geospatial analytics is used to add timing and location to traditional types of data and to build data visualizations. In this notebook we showcased various data on how to visualize spatial data.
#
#
# Thank you for reading to the end. Leave an upvote if you found the notebook helpful. Drop a comment if you have any question or contribution.
